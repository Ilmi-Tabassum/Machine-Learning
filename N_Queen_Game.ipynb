# %%
import random

def fitness(board):
    i=1
    total_attack=0
    for x in board:
        j=1
        for y in board:
            if(i!=j):
                dx = x - y
                dy = i - j
                if(abs(dx)==abs(dy) or x==y):
                   
                  total_attack=total_attack+1
            j=j+1
        i=i+1
        total_non_attack=((len(board)*(len(board)-1))-total_attack)/2
    #print(total_attack)
    return total_non_attack

# %%
def crossover(board1, board2, index):
    i=0
    new_board1 = [0, 0, 0, 0, 0, 0, 0, 0]
    new_board2 = [0, 0, 0, 0, 0, 0, 0, 0]
    while(i<len(board1)):
        if(i<index):
            new_board1[i]=board1[i]
            new_board2[i]=board2[i]
        else:
            new_board1[i]=board2[i]
            new_board2[i]=board1[i]
        i=i+1
       
    return new_board2, new_board1

# %%
def mutation(board, f):
    fit=f
    while(fit<=f):
        new_board = board
        index = random.randint(1, 8)
        mutant_gene= random.randint(1, 8)
        new_board[index - 1] = mutant_gene
        fit=fitness(new_board)
    return new_board

# %%
ultimate_list=[]
x_axis=[]
y_axis=[]
iter=1
while(iter<=12):
    n = random.randint(5, 10)
    i = 1
    randomlist = []
    while (i <= n):
        new_set = []
        j = 1
        while (j <= 8):
            number = random.randint(1, 8)
            new_set.append(number)
            j = j + 1
        randomlist.append(new_set)
        i = i + 1
    print("These are randomly generated population:\n", randomlist)
    if(len(ultimate_list)>=1):
        counter=random.randint(1,len(ultimate_list))
        ran=random.sample(range(0, len(ultimate_list)), counter)
        print("\nThese are added from old population:")
        for c in ran:
            randomlist.append(ultimate_list[c])
            print("\n",ultimate_list[c])
    rand = random.sample(range(0, len(randomlist)), 2)
    randomly_selected = [randomlist[rand[0]], randomlist[rand[1]]]
    print("\nThese are randomly selected to crossover:\n", randomly_selected)
    n = random.randint(1, 8)
    print("\nRandomly generated index number is: ", n)
    new_board1, new_board2 = crossover(randomly_selected[0], randomly_selected[1], n)
    print("\nWe get these new boards after cross-over: \n", new_board1, "\n", new_board2)
    print("\nFitness for New board 1: ", fitness(new_board1))
    print("\nFitness for New board 2: ", fitness(new_board2))
    possible_non_attack1 = ((len(new_board1) * (len(new_board1) - 1))) / 2
    possible_non_attack2 = ((len(new_board2) * (len(new_board2) - 1))) / 2
    f1 = fitness(new_board1)
    f2 = fitness(new_board2)
    if (possible_non_attack1 > f1):
        new_board1 = mutation(new_board1, f1)
        print("\nMutated New Board 1:\n", new_board1)

    if (possible_non_attack2 > f2):
        new_board2 = mutation(new_board2, f2)
        print("\nMutated New Board 2:\n", new_board2)

    f1 = fitness(new_board1)
    f2 = fitness(new_board2)
    if (f1 > f2):
        ultimate_list.append(new_board1)
        y_axis.append(f1)
    else:
        ultimate_list.append(new_board2)
        y_axis.append(f2)
    x_axis.append(iter)
    if(f1==possible_non_attack1):
        print("\nThe non-attacking board is:\n", new_board1)
        break
    elif(f2==possible_non_attack2):
        print("\nThe non-attacking board is:\n", new_board1)
        break
    iter=iter+1
# Out:
# These are randomly generated population:
#  [[4, 7, 1, 5, 5, 7, 5, 2], [1, 3, 4, 4, 8, 6, 1, 6], [5, 5, 3, 8, 7, 2, 8, 1], [4, 6, 8, 2, 1, 5, 5, 2], [7, 8, 6, 1, 6, 2, 3, 7], [5, 1, 8, 1, 1, 4, 5, 1], [2, 8, 3, 2, 4, 2, 5, 4], [3, 5, 5, 5, 6, 1, 3, 1], [6, 5, 7, 2, 4, 3, 1, 6]]
#
# These are randomly selected to crossover:
#  [[3, 5, 5, 5, 6, 1, 3, 1], [1, 3, 4, 4, 8, 6, 1, 6]]
#
# Randomly generated index number is:  3
#
# We get these new boards after cross-over:
#  [1, 3, 4, 5, 6, 1, 3, 1]
#  [3, 5, 5, 4, 8, 6, 1, 6]
#
# Fitness for New board 1:  16.0
#
# Fitness for New board 2:  20.0
#
# Mutated New Board 1:
#  [1, 3, 5, 5, 6, 1, 3, 1]
#
# Mutated New Board 2:
#  [3, 5, 5, 4, 8, 6, 4, 6]
# These are randomly generated population:
#  [[3, 6, 6, 3, 6, 4, 8, 1], [6, 2, 5, 5, 7, 4, 8, 3], [6, 4, 4, 7, 5, 6, 3, 4], [1, 7, 7, 6, 3, 8, 4, 6], [3, 8, 8, 8, 1, 6, 1, 3]]
#
# These are added from old population:
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
# These are randomly selected to crossover:
#  [[3, 6, 6, 3, 6, 4, 8, 1], [6, 4, 4, 7, 5, 6, 3, 4]]
#
# Randomly generated index number is:  2
#
# We get these new boards after cross-over:
#  [6, 4, 6, 3, 6, 4, 8, 1]
#  [3, 6, 4, 7, 5, 6, 3, 4]
#
# Fitness for New board 1:  21.0
#
# Fitness for New board 2:  21.0
#
# Mutated New Board 1:
#  [6, 4, 6, 3, 1, 4, 8, 1]
#
# Mutated New Board 2:
#  [3, 6, 4, 7, 5, 6, 8, 4]
# These are randomly generated population:
#  [[1, 8, 5, 3, 4, 2, 7, 6], [3, 8, 2, 1, 1, 7, 6, 8], [4, 2, 1, 6, 7, 2, 2, 7], [6, 1, 2, 2, 3, 6, 6, 3], [5, 1, 8, 4, 6, 8, 4, 6], [2, 5, 5, 4, 2, 2, 7, 8]]
#
# These are added from old population:
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
# These are randomly selected to crossover:
#  [[6, 1, 2, 2, 3, 6, 6, 3], [3, 8, 2, 1, 1, 7, 6, 8]]
#
# Randomly generated index number is:  2
#
# We get these new boards after cross-over:
#  [3, 8, 2, 2, 3, 6, 6, 3]
#  [6, 1, 2, 1, 1, 7, 6, 8]
#
# Fitness for New board 1:  21.0
#
# Fitness for New board 2:  19.0
#
# Mutated New Board 1:
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
# Mutated New Board 2:
#  [4, 1, 2, 2, 6, 2, 3, 7]
# These are randomly generated population:
#  [[7, 6, 5, 4, 2, 2, 8, 5], [8, 4, 7, 5, 3, 5, 5, 5], [5, 6, 5, 7, 4, 2, 5, 4], [8, 8, 6, 8, 2, 2, 3, 7], [1, 6, 2, 1, 7, 6, 3, 6]]
#
# These are added from old population:
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
# These are randomly selected to crossover:
#  [[3, 6, 4, 7, 5, 6, 8, 4], [7, 6, 5, 4, 2, 2, 8, 5]]
#
# Randomly generated index number is:  7
#
# We get these new boards after cross-over:
#  [7, 6, 5, 4, 2, 2, 8, 4]
#  [3, 6, 4, 7, 5, 6, 8, 5]
#
# Fitness for New board 1:  15.0
#
# Fitness for New board 2:  24.0
#
# Mutated New Board 1:
#  [7, 1, 5, 7, 7, 2, 5, 4]
#
# Mutated New Board 2:
#  [2, 6, 6, 1, 7, 4, 2, 8]
# These are randomly generated population:
#  [[7, 6, 6, 4, 6, 3, 6, 5], [2, 5, 1, 6, 7, 6, 4, 4], [6, 4, 1, 2, 2, 8, 3, 1], [7, 4, 6, 1, 1, 8, 1, 6], [8, 7, 7, 3, 8, 5, 3, 4], [7, 6, 4, 4, 5, 4, 2, 7], [3, 4, 5, 5, 1, 8, 3, 2], [1, 1, 8, 7, 6, 6, 6, 3], [2, 3, 2, 5, 7, 6, 3, 8], [5, 8, 8, 2, 6, 2, 7, 5]]
#
# These are added from old population:
#
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
#  [2, 6, 6, 1, 7, 4, 2, 8]
#
# These are randomly selected to crossover:
#  [[2, 6, 6, 1, 7, 4, 2, 8], [8, 7, 7, 3, 8, 5, 3, 4]]
#
# Randomly generated index number is:  6
#
# We get these new boards after cross-over:
#  [8, 7, 7, 3, 8, 5, 2, 8]
#  [2, 6, 6, 1, 7, 4, 3, 4]
#
# Fitness for New board 1:  20.0
#
# Fitness for New board 2:  23.0
#
# Mutated New Board 1:
#  [8, 7, 7, 1, 8, 5, 2, 8]
#
# Mutated New Board 2:
#  [2, 6, 6, 1, 7, 4, 1, 3]
# These are randomly generated population:
#  [[4, 4, 6, 8, 6, 2, 3, 8], [3, 1, 5, 8, 5, 2, 5, 5], [1, 5, 7, 4, 6, 7, 2, 2], [4, 6, 2, 7, 2, 5, 3, 1], [3, 8, 8, 1, 5, 3, 3, 4], [5, 2, 1, 4, 7, 1, 6, 4], [6, 8, 8, 5, 6, 2, 2, 3], [7, 7, 5, 4, 3, 3, 4, 5]]
#
# These are added from old population:
#
#  [2, 6, 6, 1, 7, 4, 1, 3]
#
#  [2, 6, 6, 1, 7, 4, 2, 8]
#
# These are randomly selected to crossover:
#  [[2, 6, 6, 1, 7, 4, 1, 3], [5, 2, 1, 4, 7, 1, 6, 4]]
#
# Randomly generated index number is:  7
#
# We get these new boards after cross-over:
#  [5, 2, 1, 4, 7, 1, 6, 3]
#  [2, 6, 6, 1, 7, 4, 1, 4]
#
# Fitness for New board 1:  24.0
#
# Fitness for New board 2:  23.0
#
# Mutated New Board 1:
#  [6, 4, 1, 7, 5, 2, 5, 7]
#
# Mutated New Board 2:
#  [7, 3, 1, 3, 5, 8, 5, 1]
# These are randomly generated population:
#  [[2, 8, 5, 8, 6, 4, 7, 3], [3, 6, 6, 4, 7, 4, 1, 5], [8, 7, 8, 8, 3, 1, 6, 5], [6, 7, 6, 6, 8, 3, 8, 4], [3, 3, 2, 1, 3, 4, 3, 3], [8, 5, 5, 2, 2, 4, 7, 7], [6, 6, 7, 6, 8, 6, 3, 5], [7, 1, 1, 4, 6, 4, 5, 1]]
#
# These are added from old population:
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
# These are randomly selected to crossover:
#  [[3, 6, 6, 4, 7, 4, 1, 5], [3, 6, 4, 7, 5, 6, 8, 4]]
#
# Randomly generated index number is:  8
#
# We get these new boards after cross-over:
#  [3, 6, 4, 7, 5, 6, 8, 4]
#  [3, 6, 6, 4, 7, 4, 1, 5]
#
# Fitness for New board 1:  23.0
#
# Fitness for New board 2:  22.0
#
# Mutated New Board 1:
#  [8, 6, 4, 2, 5, 5, 3, 4]
#
# Mutated New Board 2:
#  [3, 1, 7, 2, 5, 7, 1, 3]
# These are randomly generated population:
#  [[1, 3, 1, 2, 5, 3, 3, 4], [6, 4, 1, 4, 5, 4, 4, 6], [4, 1, 3, 6, 5, 7, 3, 1], [7, 2, 7, 3, 1, 3, 6, 7], [3, 5, 4, 1, 6, 7, 7, 4], [1, 6, 3, 3, 8, 7, 5, 5], [6, 6, 1, 4, 5, 4, 8, 4], [4, 3, 7, 8, 2, 8, 7, 1], [7, 2, 6, 6, 8, 7, 5, 3], [4, 7, 3, 5, 8, 8, 7, 1]]
#
# These are added from old population:
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
#  [2, 6, 6, 1, 7, 4, 2, 8]
#
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
#  [6, 4, 1, 7, 5, 2, 5, 7]
#
#  [3, 1, 7, 2, 5, 7, 1, 3]
#
# These are randomly selected to crossover:
#  [[7, 2, 6, 6, 8, 7, 5, 3], [6, 4, 1, 4, 5, 4, 4, 6]]
#
# Randomly generated index number is:  6
#
# We get these new boards after cross-over:
#  [6, 4, 1, 4, 5, 4, 5, 3]
#  [7, 2, 6, 6, 8, 7, 4, 6]
#
# Fitness for New board 1:  19.0
#
# Fitness for New board 2:  22.0
#
# Mutated New Board 1:
#  [6, 8, 7, 5, 5, 7, 5, 3]
#
# Mutated New Board 2:
#  [7, 2, 6, 6, 8, 7, 4, 3]
# These are randomly generated population:
#  [[6, 2, 1, 7, 2, 5, 7, 2], [4, 2, 6, 7, 4, 2, 5, 3], [1, 8, 5, 6, 5, 8, 4, 6], [2, 6, 8, 1, 2, 8, 2, 8], [2, 1, 2, 5, 8, 2, 4, 1], [6, 7, 6, 8, 7, 8, 8, 3], [8, 7, 1, 4, 4, 1, 1, 8], [3, 4, 1, 1, 4, 8, 1, 8], [1, 3, 8, 6, 7, 5, 8, 5], [1, 7, 7, 2, 6, 1, 2, 3]]
#
# These are added from old population:
#
#  [6, 4, 1, 7, 5, 2, 5, 7]
#
#  [2, 6, 6, 1, 7, 4, 2, 8]
#
#  [3, 1, 7, 2, 5, 7, 1, 3]
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
# These are randomly selected to crossover:
#  [[2, 6, 6, 1, 7, 4, 2, 8], [2, 1, 2, 5, 8, 2, 4, 1]]
#
# Randomly generated index number is:  5
#
# We get these new boards after cross-over:
#  [2, 1, 2, 5, 8, 4, 2, 8]
#  [2, 6, 6, 1, 7, 2, 4, 1]
#
# Fitness for New board 1:  20.0
#
# Fitness for New board 2:  22.0
#
# Mutated New Board 1:
#  [4, 1, 8, 6, 3, 1, 1, 1]
#
# Mutated New Board 2:
#  [2, 6, 6, 1, 4, 2, 7, 8]
# These are randomly generated population:
#  [[7, 3, 3, 7, 3, 4, 6, 3], [2, 6, 3, 3, 8, 6, 3, 6], [2, 1, 5, 4, 1, 4, 2, 8], [7, 5, 7, 2, 8, 6, 2, 4], [1, 1, 4, 5, 2, 7, 7, 2], [2, 4, 2, 1, 4, 8, 3, 4], [2, 8, 3, 8, 3, 6, 6, 6], [8, 1, 3, 3, 1, 3, 3, 8], [5, 5, 8, 8, 7, 6, 6, 5], [7, 4, 8, 5, 6, 2, 7, 2]]
#
# These are added from old population:
#
#  [6, 4, 1, 7, 5, 2, 5, 7]
#
# These are randomly selected to crossover:
#  [[7, 4, 8, 5, 6, 2, 7, 2], [2, 6, 3, 3, 8, 6, 3, 6]]
#
# Randomly generated index number is:  7
#
# We get these new boards after cross-over:
#  [2, 6, 3, 3, 8, 6, 3, 2]
#  [7, 4, 8, 5, 6, 2, 7, 6]
#
# Fitness for New board 1:  21.0
#
# Fitness for New board 2:  22.0
#
# Mutated New Board 1:
#  [2, 6, 4, 5, 2, 6, 3, 7]
#
# Mutated New Board 2:
#  [3, 7, 1, 5, 1, 2, 4, 6]
# These are randomly generated population:
#  [[7, 8, 8, 3, 8, 4, 1, 6], [2, 6, 5, 7, 3, 7, 6, 3], [8, 8, 8, 5, 4, 6, 6, 2], [1, 5, 8, 3, 8, 3, 5, 2], [7, 8, 5, 5, 8, 1, 3, 7], [3, 3, 4, 6, 7, 4, 2, 8]]
#
# These are added from old population:
#
#  [3, 7, 1, 5, 1, 2, 4, 6]
#
#  [3, 1, 7, 2, 5, 7, 1, 3]
#
#  [7, 2, 6, 6, 8, 7, 4, 3]
#
#  [2, 6, 6, 1, 7, 4, 1, 3]
#
#  [2, 6, 6, 1, 4, 2, 7, 8]
#
#  [3, 6, 4, 7, 5, 6, 8, 4]
#
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
#  [6, 4, 1, 7, 5, 2, 5, 7]
#
#  [2, 6, 6, 1, 7, 4, 2, 8]
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
# These are randomly selected to crossover:
#  [[3, 5, 5, 4, 8, 6, 4, 6], [3, 6, 4, 7, 5, 6, 8, 4]]
#
# Randomly generated index number is:  6
#
# We get these new boards after cross-over:
#  [3, 6, 4, 7, 5, 6, 4, 6]
#  [3, 5, 5, 4, 8, 6, 8, 4]
#
# Fitness for New board 1:  22.0
#
# Fitness for New board 2:  20.0
#
# Mutated New Board 1:
#  [8, 6, 4, 7, 5, 6, 4, 7]
#
# Mutated New Board 2:
#  [8, 5, 4, 1, 7, 6, 8, 4]
# These are randomly generated population:
#  [[8, 7, 2, 2, 8, 6, 3, 7], [3, 6, 4, 4, 5, 3, 5, 3], [3, 6, 3, 2, 4, 4, 3, 5], [4, 6, 5, 7, 5, 8, 6, 8], [1, 1, 3, 7, 4, 8, 4, 8], [7, 5, 2, 6, 6, 6, 6, 2], [8, 4, 6, 7, 1, 6, 2, 1], [1, 8, 7, 2, 1, 4, 6, 3]]
#
# These are added from old population:
#
#  [2, 6, 6, 1, 7, 4, 2, 8]
#
#  [6, 4, 1, 7, 5, 2, 5, 7]
#
#  [2, 6, 6, 1, 4, 2, 7, 8]
#
#  [2, 6, 6, 1, 7, 4, 1, 3]
#
#  [3, 8, 2, 2, 3, 6, 6, 5]
#
#  [3, 1, 7, 2, 5, 7, 1, 3]
#
#  [3, 5, 5, 4, 8, 6, 4, 6]
#
# These are randomly selected to crossover:
#  [[6, 4, 1, 7, 5, 2, 5, 7], [2, 6, 6, 1, 7, 4, 1, 3]]
#
# Randomly generated index number is:  5
#
# We get these new boards after cross-over:
#  [2, 6, 6, 1, 7, 2, 5, 7]
#  [6, 4, 1, 7, 5, 4, 1, 3]
#
# Fitness for New board 1:  23.0
#
# Fitness for New board 2:  23.0
#
# Mutated New Board 1:
#  [3, 5, 7, 1, 8, 4, 7, 1]
#
# Mutated New Board 2:
#  [7, 3, 1, 2, 8, 6, 7, 3]

# %%
if(possible_non_attack1>f1 and possible_non_attack2>f2):
    print("\nCreating new population set")
    n = random.randint(5, 10)
    i=1
    new_population=[]
    while(i<=n):
        new_set=[]
        j=1
        while(j<=8):
            number = random.randint(1, 8)
            new_set.append(number)
            j=j+1
        new_population.append(new_set)
        i=i+1
    print("\nNew generated population is: ", new_population)
# Out:
# Creating new population set
#
# New generated population is:  [[7, 7, 6, 4, 6, 2, 5, 8], [8, 4, 7, 8, 4, 6, 7, 4], [7, 6, 5, 2, 4, 8, 2, 3], [1, 4, 2, 2, 8, 1, 6, 5], [2, 7, 3, 4, 4, 1, 4, 8], [7, 1, 8, 8, 1, 5, 5, 6], [3, 2, 2, 2, 6, 4, 3, 8], [1, 3, 2, 1, 4, 6, 7, 4], [8, 3, 6, 6, 5, 4, 8, 3]]
